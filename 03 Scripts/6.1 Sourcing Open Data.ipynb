# %% [markdown]
# # TASK 6.1.
# ## 1. Import libraries and dataset
# ## 2. Data clean-up, wrangling and consistency checks
# ## 3. Basic descriptive statistical analysis
# ## 4. Export clean dataset

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Import libraries and dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path
path = r'/Users/mariliamachado/Documents/CareerFoundry/Data Immersion/Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Berlin_crimes.csv'))

# %% [markdown]
# ## 2. Data clean-up, wrangling and consistency checks

# %%
df.head()
# Out:
#    Year District   Code           Location  Robbery  Street_robbery  Injury  \
# 0  2012    Mitte  10111     Tiergarten Süd       70              46     586
# 1  2012    Mitte  10112  Regierungsviertel       65              29     474
# 2  2012    Mitte  10113     Alexanderplatz      242             136    1541
# 3  2012    Mitte  10114  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte  10221        Moabit West      130              51     629
#
#    Agg_assault  Threat  Theft  Car  From_car  Bike  Burglary  Fire  Arson  \
# 0          194     118   2263   18       328   120        68    16      4
# 1          123     142   3203   10       307   170        37    10      4
# 2          454     304   8988   81       792   822       275    49     27
# 3           60      66   1916   86       192   396       131    14      5
# 4          185     199   2470   94       410   325       161    42     22
#
#    Damage  Graffiti  Drugs  Local
# ...

# %%
# Drop Code column
df = df.drop(columns = ['Code'])
df.head()
# Out:
#    Year District           Location  Robbery  Street_robbery  Injury  \
# 0  2012    Mitte     Tiergarten Süd       70              46     586
# 1  2012    Mitte  Regierungsviertel       65              29     474
# 2  2012    Mitte     Alexanderplatz      242             136    1541
# 3  2012    Mitte  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte        Moabit West      130              51     629
#
#    Agg_assault  Threat  Theft  Car  From_car  Bike  Burglary  Fire  Arson  \
# 0          194     118   2263   18       328   120        68    16      4
# 1          123     142   3203   10       307   170        37    10      4
# 2          454     304   8988   81       792   822       275    49     27
# 3           60      66   1916   86       192   396       131    14      5
# 4          185     199   2470   94       410   325       161    42     22
#
#    Damage  Graffiti  Drugs  Local
# 0     273        26    171   1032
# 1     380       124     98    870
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Year              0
# District          0
# Location          0
# Robbery           0
# Street_robbery    0
# Injury            0
# Agg_assault       0
# Threat            0
# Theft             0
# Car               0
# From_car          0
# Bike              0
# Burglary          0
# Fire              0
# Arson             0
# Damage            0
# Graffiti          0
# Drugs             0
# Local             0
# dtype: int64

# %%
# Change confusing column names
df.rename(columns = {'Car' : 'Car_theft',
                    'From_car' : 'Car_burglary',
                    'Bike_burglary' : 'Bike_theft',
                    'Drugs' : 'Drugs_possession',
                     'Local' : 'Antisocial_behavior'}, inplace = True)

# %%
df.head()
# Out:
#    Year District           Location  Robbery  Street_robbery  Injury  \
# 0  2012    Mitte     Tiergarten Süd       70              46     586
# 1  2012    Mitte  Regierungsviertel       65              29     474
# 2  2012    Mitte     Alexanderplatz      242             136    1541
# 3  2012    Mitte  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte        Moabit West      130              51     629
#
#    Agg_assault  Threat  Theft  Car_theft  Car_burglary  Bike_theft  Burglary  \
# 0          194     118   2263         18           328         120        68
# 1          123     142   3203         10           307         170        37
# 2          454     304   8988         81           792         822       275
# 3           60      66   1916         86           192         396       131
# 4          185     199   2470         94           410         325       161
#
#    Fire  Arson  Damage  Graffiti  Drugs_possession  Antisocial_behavior
# ...

# %%
# Check data types and general info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1200 non-null   int64
#  1   District             1200 non-null   object
#  2   Location             1200 non-null   object
#  3   Robbery              1200 non-null   int64
#  4   Street_robbery       1200 non-null   int64
#  5   Injury               1200 non-null   int64
#  6   Agg_assault          1200 non-null   int64
#  7   Threat               1200 non-null   int64
#  8   Theft                1200 non-null   int64
#  9   Car_theft            1200 non-null   int64
#  10  Car_burglary         1200 non-null   int64
#  11  Bike_theft           1200 non-null   int64
#  12  Burglary             1200 non-null   int64
#  13  Fire                 1200 non-null   int64
#  14  Arson                1200 non-null   int64
# ...

# %%
# Find duplicates
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Year, District, Location, Robbery, Street_robbery, Injury, Agg_assault, Threat, Theft, Car_theft, Car_burglary, Bike_theft, Burglary, Fire, Arson, Damage, Graffiti, Drugs_possession, Antisocial_behavior]
# Index: []

# %% [markdown]
# ## 3. Basic descriptive statistical analysis

# %%
df.describe()
# Out:
#               Year      Robbery  Street_robbery       Injury  Agg_assault  \
# count  1200.000000  1200.000000     1200.000000  1200.000000  1200.000000
# mean   2015.500000    34.233333       18.744167   276.334167    68.750000
# std       2.292243    37.093447       22.171153   243.697780    71.113959
# min    2012.000000     0.000000        0.000000     0.000000     0.000000
# 25%    2013.750000    10.000000        5.000000   108.000000    22.000000
# 50%    2015.500000    22.000000       11.000000   204.500000    44.000000
# 75%    2017.250000    42.000000       23.000000   361.000000    86.000000
# max    2019.000000   242.000000      169.000000  1966.000000   500.000000
#
#             Threat         Theft    Car_theft  Car_burglary   Bike_theft  \
# count  1200.000000   1200.000000  1200.000000   1200.000000  1200.000000
# mean     92.583333   1492.307500    42.505833    215.275000   197.706667
# std      68.455264   1364.442501    28.710164    150.031343   178.704771
# ...

# %% [markdown]
# ## 4. Export clean dataset

# %%
# Export clean dataset
df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Berlin_crimes_clean.csv'))
